# %%
import matplotlib.pyplot as plt
import matplotlib.image  as mpimg
import statsmodels.tsa.seasonal as smt
import numpy as np 
import pandas as pd 
import random
import math
import datetime as dt
from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import plotly
# import tensorflow as tf
# import tensorflow_addons as tfa
from math import sqrt
# print(tf.__version__)

# %%
msft=pd.read_csv('MSFT_indicators_final.csv')
msft = msft.drop(['Date','5 DAYS BR','Adj Close','Open','High','Low','Close','Volume','H-L','O-C','H-O','O-L'], axis=1)

# %%
import seaborn as sns
MSFT_corr=msft.corr()
test = sns.clustermap(MSFT_corr,annot=True,cmap='coolwarm_r',figsize=(15, 15))

# %%
NVDA=pd.read_csv('NVDA_indicators_final.csv')
NVDA = NVDA.drop(['Date','5 DAYS BR','Adj Close','Open','High','Low','Close','Volume','H-L','O-C','H-O','O-L'], axis=1)

# %%
NVDA_corr=NVDA.corr()
sns.clustermap(NVDA_corr,annot=True,cmap='coolwarm_r',figsize=(15, 15))

# %%
INTC=pd.read_csv('INTC_indicators_final.csv')
INTC = INTC.drop(['Date','5 DAYS BR','Adj Close','Open','High','Low','Close','Volume','H-L','O-C','H-O','O-L'], axis=1)

# %%
INTC_corr=INTC.corr()
sns.clustermap(INTC_corr,annot=True,cmap='coolwarm_r',figsize=(15, 15))
